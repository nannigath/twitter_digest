# %%
import re
import os
import json
import time
import requests
import pandas as pd
from selenium import webdriver
from urllib.parse import urlparse
from datetime import datetime, timedelta
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, TimeoutException
from selenium.webdriver.support.ui import WebDriverWait

# %%
class WebDriverManager:
    """
    Manages WebDriver initialization, configuration, and browser sessions.
    """
    def __init__(self, auth_token=None, headless=True):
       
        self.driver = None
        self.auth_token = auth_token
        self.headless = headless
    
    def initialize_driver(self):
        """
        Initialize and configure the Selenium WebDriver.
        """
        options = webdriver.ChromeOptions()
        options.add_argument("--verbose")
        options.add_argument('--no-sandbox')
        options.add_argument('--disable-gpu')
        options.add_argument("--window-size=1920, 1200")
        options.add_argument('--disable-dev-shm-usage')
        options.headless = self.headless
        
        self.driver = webdriver.Chrome(options=options)
        self.driver.get("https://x.com")
        
        if self.auth_token:
            self._set_auth_token()
        
        return self.driver
    
    def _set_auth_token(self):
        """
        Set authentication token as a cookie.
        """
        if not self.auth_token:
            raise ValueError("Access token is missing. Please configure it properly.")
        
        expiration = (datetime.now() + timedelta(days=14)).strftime("%Y-%m-%d")
        cookie_script = f"document.cookie = 'auth_token={self.auth_token}; expires={expiration}; path=/';"
        self.driver.execute_script(cookie_script)
    
    def get_current_tweet(self):
        """
        Retrieve the currently visible tweet on the page.
        """
        try:
            current_tweet_element = self.driver.find_element(By.XPATH, "//article[@role='article']")
            return current_tweet_element if current_tweet_element else None
        except Exception as e:
            print(f"Error while fetching the current tweet: {str(e)}")
            return None
    
    def close(self):
        """
        Close the WebDriver and end the session.
        """
        if self.driver:
            self.driver.quit()

# %%
class TwitterScraper:
    """
    Handles tweet extraction, processing, and analysis.
    """
    
    def __init__(self, driver_manager=None):
        self.driver_manager = driver_manager or WebDriverManager()
        self.driver = self.driver_manager.driver
    
    def _get_first_tweet(self, timeout=10, max_retries=5, retry_delay=2):
        """
        Retrieve the first tweet element from the page.
        """
        retries = 0
        while retries < max_retries:
            try:
                WebDriverWait(self.driver, timeout).until(
                    lambda d: d.find_elements(By.XPATH, "//article[@data-testid='tweet']")
                )
                return self.driver.find_element(By.XPATH, "//article[@data-testid='tweet']")
            except TimeoutException:
                retries += 1
                time.sleep(retry_delay)
        
        return None
    
    def fetch_tweets_list(self, url, start_date, end_date, time_threshold_minutes=2):
        """
        Fetch tweets from a given tweet list URL within a specified date range and assign thread numbers.
        """
        if not self.driver:
            self.driver_manager.initialize_driver()
        
        self.driver.get(url)
        start_date_obj = datetime.strptime(start_date, "%Y-%m-%d")
        end_date_obj = datetime.strptime(end_date, "%Y-%m-%d")
        count = 0
       
        tweets = []
        while True:
           
            tweet_element = self._get_first_tweet()
            tweet_data = self._process_tweet(tweet_element)
            if not tweet_data:
                continue
            
            tweet_date = datetime.strptime(tweet_data["date"], "%Y-%m-%d")
            tweets.append(tweet_data)
            if tweet_date < start_date_obj:
                if not tweet_data['is_reposted']:
                    break
            elif tweet_date > end_date_obj:
                count+=1
                self._delete_first_tweet()
                
                continue
            
            self._delete_first_tweet()
        
        df = pd.DataFrame(tweets)
        
        if not df.empty:
            df["datetime"] = pd.to_datetime(df["date"] + " " + df["time"])
            df.sort_values(by=["author_name", "datetime"], inplace=True)
            
            thread_numbers = []
            thread_count = 0
            
            for author, group in df.groupby("author_name"):
                last_datetime = None
                for idx, row in group.iterrows():
                    if last_datetime is None or (row["datetime"] - last_datetime).total_seconds() > time_threshold_minutes * 60:
                        thread_count += 1
                    thread_numbers.append(thread_count)
                    last_datetime = row["datetime"]
            
            df["thread_number"] = thread_numbers
            df.drop(columns=["datetime"], inplace=True)
        
        return df
    
    def _delete_first_tweet(self):
        """
        Remove the first tweet from the page 
        """
        try:
            tweet_element = self.driver.find_element(By.XPATH, "//article[@data-testid='tweet'][1]")
            self.driver.execute_script("arguments[0].remove();", tweet_element)
        except NoSuchElementException:
            print("No tweet to delete.")
    
    def get_element_text(self, parent, xpath):
        try:
            return parent.find_element(By.XPATH, xpath).text
        except NoSuchElementException:
            return ""
    
    def get_element_attribute(self, parent, selector, attribute):
        try:
            return parent.find_element(By.CSS_SELECTOR, selector).get_attribute(attribute)
        except NoSuchElementException:
            return ""
    
    def get_tweet_url(self, tweet_element):
        try:
            link_element = tweet_element.find_element(By.XPATH, ".//a[contains(@href, '/status/')]")
            return link_element.get_attribute("href")
        except NoSuchElementException:
            return ""
    
    def get_mentioned_urls(self, tweet_element):
        try:
            link_elements = tweet_element.find_elements(By.XPATH, ".//a[contains(@href, 'http')]")
            return [elem.get_attribute("href") for elem in link_elements]
        except NoSuchElementException:
            return []
    
    def is_retweet(self, tweet_element):
        try:
            return bool('reposted' in tweet_element.find_element(By.XPATH,'.//span').text)
        except NoSuchElementException:
            return False
    
    def get_media_type(self, tweet_element):
        if tweet_element.find_elements(By.CSS_SELECTOR, "div[data-testid='videoPlayer']"):
            return "Video"
        if tweet_element.find_elements(By.CSS_SELECTOR, "div[data-testid='tweetPhoto']"):
            return "Image"
        return "No media"
    
    def get_images_urls(self, tweet_element):
        image_elements = tweet_element.find_elements(By.XPATH, ".//div[@data-testid='tweetPhoto']//img")
        return [img.get_attribute("src") for img in image_elements]
    
    def _process_tweet(self, tweet_element):
        """
        Process a single tweet element and extract relevant information.
        """
        try:
            author_details = self.get_element_text(tweet_element, ".//div[@data-testid='User-Name']")
            parts = author_details.split("\n")
            author_name, author_handle = parts[0], parts[1] if len(parts) > 1 else ""
            
            tweet_datetime_str = self.get_element_attribute(tweet_element, "time", "datetime")
            tweet_datetime = datetime.strptime(tweet_datetime_str, "%Y-%m-%dT%H:%M:%S.000Z")
            tweet_date = tweet_datetime.date()
            tweet_time = tweet_datetime.time()
            
            tweet_data = {
                "text": self.get_element_text(tweet_element, ".//div[@data-testid='tweetText']"),
                "author_name": author_name,
                "author_handle": author_handle,
                "date": tweet_date.strftime('%Y-%m-%d'),
                "time": tweet_time.strftime('%H:%M:%S'),
                "lang": self.get_element_attribute(tweet_element, "div[data-testid='tweetText']", "lang"),
                "tweet_url": self.get_tweet_url(tweet_element),
                "mentioned_urls": self.get_mentioned_urls(tweet_element),
                "is_reposted": self.is_retweet(tweet_element),
                "media_type": self.get_media_type(tweet_element),
                "image_urls": self.get_images_urls(tweet_element)
            }
            return tweet_data
        except Exception as e:
            print(f"Error processing tweet: {str(e)}")
            return None

    def download_images(self, df, output_dir='downloaded_images', timeout=10, chunk_size=8192, delay=1):
        """
        Download images from tweets and save them in a given folder
        """
   
        os.makedirs(output_dir, exist_ok=True)
        
        for _, row in df.iterrows():
            if not row.get('image_urls'):
                continue  # Skip rows without image URLs
            
            # Parse tweet details for naming files
            url_parts = urlparse(row['tweet_url'])
            twitter_name = url_parts.path.split('/')[1]
            tweet_id = url_parts.path.split('/')[-1]
            
            for i, image_url in enumerate(row['image_urls'], start=1):
                image_id = f"{twitter_name}__{tweet_id}_{i}"
                image_path = os.path.join(output_dir, f"{image_id}.jpg")
                
                # Skip download if the file already exists
                if os.path.exists(image_path):
                    print(f"Image already exists: {image_id}")
                    continue
                
                try:
                    # Download image
                    response = requests.get(image_url, stream=True, timeout=timeout)
                    response.raise_for_status()
                    
                    with open(image_path, 'wb') as file:
                        for chunk in response.iter_content(chunk_size=chunk_size):
                            file.write(chunk)
                    
                    print(f"Successfully downloaded image: {image_id}")
                    
                    # Delay to prevent rate-limiting
                    time.sleep(delay)
                
                except requests.exceptions.RequestException as e:
                    print(f"Error downloading image: {image_id}")
                    print(f"Error message: {str(e)}")
    
        print("Image download completed.")

# %%
auth_token = '8447d678bdaf27e220dcfb3fda5c34fe48179dc9'
driver_manager = WebDriverManager(auth_token=auth_token)
driver_manager.initialize_driver()
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="9680dfd914cb6a17af1a02331dabfea4")>

# %%
twitter_scraper = TwitterScraper(driver_manager)

# %%
tweets = twitter_scraper.fetch_tweets_list(
        "https://x.com/i/lists/1866834968594317670",
        start_date="2024-12-08",
        end_date="2024-12-15",
    )

# %%
tweets
# Out:
#                                                  text         author_name  \
# 13   Explore On-Prem Agents with \n@LangChainAI\n'...       AI Makerspace
# 32  New release from Meta FAIR —  Meta Motivo is a...          AI at Meta
# 33  More details, including links to the research ...          AI at Meta
# 37  Comments from \n@Klarna\n CEO \n@klarnaseb\n o...       Alec Coughlin
# 47  Great conversation with \n@LangChainAI\n CEO H...        Charu Sharma
# 48   Agentic Travel Planner\n\nLangGraph (\n@langc...          CopilotKit
# 11  I remember last week when I read about this in...       Daniel Torres
# 52  In case you missed it, earlier this week we la...     DeepLearning.AI
# 39  OpenAI's o1 model and its pro mode enhance per...     DeepLearning.AI
# 24  Fascinated by AI, Matt Struble gained the skil...     DeepLearning.AI
# 18  With the Deep Learning Specialization, availab...     DeepLearning.AI
# 41  Applications open on Dec 20 for the Research S...           Google AI
# 50  Join our VP (Drastic) Research, Gemini co-Tech...     Google DeepMind
# 51  Watch → \n@YouTube\n https://goo.gle/3ZB09Od\n...     Google DeepMind
# 42  Project Astra helped Robbie identify his myste...     Google DeepMind
# 14  Human in the loop is one of the most requested...        Hard Kothari
# 19  Congrats to \n@ilyasut\n, \n@OriolVinyalsML\n ...           Jeff Dean
# 4   This weekend learn how to build a legal docume...           Jerry Liu
# 49  Check out how to make a LangGraph Travel plann...           LangChain
# 40  SQL Bot is an AI assistant integrated into \n@...           LangChain
# 23   Join experts from \n@confluentinc\n and \n@el...           LangChain
# 17  Human-in-the-loop example with LangGraph\n\ngo...           LangChain
# 15  `interrupt`: Making it easier to build human-i...           LangChain
# 12  Build an AI Research Agent\n\nFrom this year's...           LangChain
# 7   Community Content\n\nHow LangGraph is Changing...           LangChain
# 6   Exploring Open Canvas: The Open Source Alterna...           LangChain
# 2    Brainstormers\n\nOne of my main use cases for...           LangChain
# 1   Building a GraphRAG Agent With Neo4j and Milvu...           LangChain
# 53  Parse only exactly what you need with LlamaPar...          LlamaIndex
# 26  Learn "everything you need to know about Llama...          LlamaIndex
# 16  We’re introducing a brand-new tutorial  on how...          LlamaIndex
# 46  Welcome to the third day of the NeurIPS main c...  NeurIPS Conference
# 45  Oral presentations will be held during these t...  NeurIPS Conference
# 44  Interesting and inspiring keynote talk by Dani...  NeurIPS Conference
# 38  The Test of Time session will take place at 1:...  NeurIPS Conference
# 34  It is happening TODAY!!!\n\nThe NeurIPS2024 To...  NeurIPS Conference
# 28  Live!!! Test of Time session is underway. The ...  NeurIPS Conference
# 27  Test of Time session is underway. And here are...  NeurIPS Conference
# 25  Join us in West Exhibition Hall C, B3 for Rosa...  NeurIPS Conference
# 22  NeurIPS acknowledges that the cultural general...  NeurIPS Conference
# 43  Day 7: Projects in ChatGPT—a new way to organi...              OpenAI
# 35             Elon Musk wanted an OpenAI for-profit.              OpenAI
# 36                                                                 OpenAI
# 29  Introducing Projects—an easy way to organize c...              OpenAI
# 30        You can also use ChatGPT search and canvas.              OpenAI
# 31  You can create projects at http://chatgpt.com ...              OpenAI
# 54  Such a great honor, thanks a lot \n@NeurIPSCon...       Oriol Vinyals
# 5   The Guide for building with Llama Models \n\nO...      Sanyam Bhutani
# 0   Check out our latest blog post about MiniVLA, ...     Stanford AI Lab
# 3                          That's Qwen 2.5 coder 14b!      Subhash Peshwa
# 20  Want a smaller VLA that performs better? We ju...     Suneel Belkhale
# 21                                                                    xAI
# 8   Grok is now free for everyone\n\nOur AI assist...                 xAI
# 9   API access\n\nA month ago, we launched the pub...                 xAI
# 10                   Read our full announcement here:                 xAI
#
#        author_handle        date      time lang  \
# 13     @AIMakerspace  2024-12-14  18:30:00   en
# 32         @AIatMeta  2024-12-13  20:15:37   en
# 33         @AIatMeta  2024-12-13  20:15:37   en
# 37    @Alec_Coughlin  2024-12-13  18:57:21   en
# 47        @charu1603  2024-12-13  16:54:45   en
# 48       @CopilotKit  2024-12-13  17:09:48   en
# 11   @danieltorres_c  2024-12-14  19:48:44   en
# 52   @DeepLearningAI  2024-12-13  15:34:24   en
# 39   @DeepLearningAI  2024-12-13  18:59:59   en
# 24   @DeepLearningAI  2024-12-13  23:00:06   en
# 18   @DeepLearningAI  2024-12-14  16:00:09   en
# 41         @GoogleAI  2024-12-13  18:19:04   en
# 50   @GoogleDeepMind  2024-12-13  16:28:33   en
# 51   @GoogleDeepMind  2024-12-13  16:28:34   en
# 42   @GoogleDeepMind  2024-12-13  18:08:43   en
# 14      @HardKothari  2024-12-14  18:44:21   en
# 19         @JeffDean  2024-12-13  07:15:49   en
# 4        @jerryjliu0  2024-12-15  01:43:46   en
# 49      @LangChainAI  2024-12-13  16:45:00   en
# 40      @LangChainAI  2024-12-13  18:30:00   en
# 23      @LangChainAI  2024-12-14  01:41:24   en
# 17      @LangChainAI  2024-12-14  16:25:13   en
# 15      @LangChainAI  2024-12-14  18:00:01   en
# 12      @LangChainAI  2024-12-14  19:42:43   en
# 7       @LangChainAI  2024-12-14  21:30:00   en
# 6       @LangChainAI  2024-12-15  00:49:00   en
# 2       @LangChainAI  2024-12-15  16:00:01   en
# 1       @LangChainAI  2024-12-15  18:00:00   en
# 53      @llama_index  2024-12-13  14:59:56   en
# 26      @llama_index  2024-12-13  22:41:23   en
# 16      @llama_index  2024-12-14  17:50:17   en
# 46      @NeurIPSConf  2024-12-13  17:19:34   en
# 45      @NeurIPSConf  2024-12-13  17:22:31   en
# 44      @NeurIPSConf  2024-12-13  17:37:02   en
# 38      @NeurIPSConf  2024-12-13  19:00:37   en
# 34      @NeurIPSConf  2024-12-13  20:00:02   en
# 28      @NeurIPSConf  2024-12-13  21:54:12   en
# 27      @NeurIPSConf  2024-12-13  22:14:55   en
# 25      @NeurIPSConf  2024-12-13  22:54:14   en
# 22      @NeurIPSConf  2024-12-14  02:30:50   en
# 43           @OpenAI  2024-12-13  17:50:32   en
# 35           @OpenAI  2024-12-13  19:34:58   en
# 36           @OpenAI  2024-12-13  19:34:58
# 29           @OpenAI  2024-12-13  20:59:44   en
# 30           @OpenAI  2024-12-13  20:59:46   en
# 31           @OpenAI  2024-12-13  20:59:46   en
# 54   @OriolVinyalsML  2024-11-27  18:22:55   en
# 5    @bhutanisanyam1  2024-12-14  15:10:25   en
# 0     @StanfordAILab  2024-12-15  18:19:05   en
# 3    @Subhash_Peshwa  2024-12-15  08:26:40   en
# 20  @suneel_belkhale  2024-12-13  18:03:59   en
# 21              @xai  2024-12-14  02:37:50
# 8               @xai  2024-12-14  21:27:18   en
# 9               @xai  2024-12-14  21:27:20   en
# 10              @xai  2024-12-14  21:27:21   en
#
#                                             tweet_url  \
# 13  https://x.com/AIMakerspace/status/186800050479...
# 32  https://x.com/AIatMeta/status/1867664693319586289
# 33  https://x.com/AIatMeta/status/1867664695072895489
# 37  https://x.com/Alec_Coughlin/status/18676449984...
# 47  https://x.com/charu1603/status/186761414562727...
# 48  https://x.com/CopilotKit/status/18676179316196...
# 11  https://x.com/danieltorres_c/status/1868020317...
# 52  https://x.com/DeepLearningAI/status/1867593926...
# 39  https://x.com/DeepLearningAI/status/1867645660...
# 24  https://x.com/DeepLearningAI/status/1867706089...
# 18  https://x.com/DeepLearningAI/status/1867962792...
# 41  https://x.com/GoogleAI/status/1867635363340333370
# 50  https://x.com/GoogleDeepMind/status/1867607552...
# 51  https://x.com/GoogleDeepMind/status/1867607556...
# 42  https://x.com/GoogleDeepMind/status/1867632758...
# 14  https://x.com/HardKothari/status/1868004115114...
# 19  https://x.com/JeffDean/status/1867468451272700302
# 4   https://x.com/jerryjliu0/status/18681096657726...
# 49  https://x.com/LangChainAI/status/1867611691061...
# 40  https://x.com/LangChainAI/status/1867638115965...
# 23  https://x.com/LangChainAI/status/1867746682907...
# 17  https://x.com/LangChainAI/status/1867969101119...
# 15  https://x.com/LangChainAI/status/1867992959381...
# 12  https://x.com/LangChainAI/status/1868018803013...
# 7   https://x.com/LangChainAI/status/1868045801957...
# 6   https://x.com/LangChainAI/status/1868095881234...
# 2   https://x.com/LangChainAI/status/1868325148190...
# 1   https://x.com/LangChainAI/status/1868355340770...
# 53  https://x.com/llama_index/status/1867585249829...
# 26  https://x.com/llama_index/status/1867701379361...
# 16  https://x.com/llama_index/status/1867990509899...
# 46  https://x.com/NeurIPSConf/status/1867620389771...
# 45  https://x.com/NeurIPSConf/status/1867621133643...
# 44  https://x.com/NeurIPSConf/status/1867624786123...
# 38  https://x.com/NeurIPSConf/status/1867645819534...
# 34  https://x.com/NeurIPSConf/status/1867660771510...
# 28  https://x.com/NeurIPSConf/status/1867689503814...
# 27  https://x.com/NeurIPSConf/status/1867694719398...
# 25  https://x.com/NeurIPSConf/status/1867704613220...
# 22  https://x.com/NeurIPSConf/status/1867759121023...
# 43    https://x.com/OpenAI/status/1867628181974290752
# 35    https://x.com/OpenAI/status/1867654463588123030
# 36    https://x.com/OpenAI/status/1867654464934396123
# 29    https://x.com/OpenAI/status/1867675796950987146
# 30    https://x.com/OpenAI/status/1867675804286824565
# 31    https://x.com/OpenAI/status/1867675806790824404
# 54  https://x.com/OriolVinyalsML/status/1861838125...
# 5   https://x.com/bhutanisanyam1/status/1867950277...
# 0   https://x.com/StanfordAILab/status/18683601447...
# 3   https://x.com/Subhash_Peshwa/status/1868211057...
# 20  https://x.com/suneel_belkhale/status/186763156...
# 21       https://x.com/xai/status/1867760881750388912
# 8        https://x.com/xai/status/1868045124028268983
# 9        https://x.com/xai/status/1868045132760842734
# 10       https://x.com/xai/status/1868045134547554650
#
#                                        mentioned_urls  is_retweet media_type  \
# 13  [https://t.co/u5FfbNm3fU, https://t.co/u5FfbNm...       False   No media
# 32                                                 []       False      Video
# 33  [https://t.co/2aaLeTmU5T, https://t.co/2aaLeTm...       False   No media
# 37                                                 []       False      Image
# 47                          [https://t.co/51QxgUpJgN]       False      Image
# 48                          [https://t.co/T7YMvNOuVS]       False      Video
# 11                                                 []       False   No media
# 52                          [https://t.co/7hWI3uJXSb]       False      Video
# 39  [https://t.co/VRUKvaYSpL, https://t.co/VRUKvaY...       False   No media
# 24                          [https://t.co/uiVlDN5Wyo]       False      Video
# 18                          [https://t.co/Ezkdmgv7W9]       False      Video
# 41  [https://t.co/SikrYfpltT, https://t.co/SikrYfp...       False   No media
# 50                                                 []       False      Video
# 51  [https://t.co/jvyctLn8T5, https://t.co/yt5f3RS...       False   No media
# 42                                                 []       False      Video
# 14                                                 []       False      Image
# 19                                                 []       False   No media
# 4                                                  []       False      Image
# 49                          [https://t.co/xNZhw0nOu3]       False      Image
# 40                                                 []       False      Image
# 23                                                 []       False   No media
# 17                          [https://t.co/WMyMRtOFtT]       False      Image
# 15  [https://t.co/OOXgBol89h, https://t.co/CSp1C5n...       False      Image
# 12                          [https://t.co/04C1RNiAji]       False      Image
# 7                           [https://t.co/cx0es3QPpg]       False      Image
# 6                           [https://t.co/MdieorCVut]       False      Image
# 2                           [https://t.co/jjMXAN58OT]       False      Image
# 1                           [https://t.co/CxA4kFNji7]       False      Image
# 53                                                 []       False      Image
# 26                                                 []       False      Image
# 16                                                 []       False      Image
# 46                          [https://t.co/rrsA7IkFmd]       False   No media
# 45                          [https://t.co/ecm0IAnTOG]       False   No media
# 44                          [https://t.co/rrsA7IkFmd]       False      Image
# 38                          [https://t.co/i1NqhW7w8U]       False      Image
# 34                                                 []       False      Image
# 28                          [https://t.co/i1NqhW7w8U]       False      Image
# 27                          [https://t.co/i1NqhW7w8U]       False      Image
# 25                          [https://t.co/7fwcCkviQt]       False      Image
# 22                                                 []       False   No media
# 43  [https://t.co/Dt7wzatS6l, https://t.co/Dt7wzat...       False   No media
# 35  [https://t.co/wjDRN1ExX4, https://t.co/wjDRN1E...       False   No media
# 36                                                 []       False      Image
# 29                                                 []       False      Video
# 30                                                 []       False      Video
# 31                          [https://t.co/nYW5KO1aIg]       False   No media
# 54                                                 []       False      Image
# 5                           [https://t.co/iwM2c4gKIV]       False      Image
# 0   [https://t.co/6TvEMWGBSF, https://t.co/6TvEMWG...       False   No media
# 3                                                  []       False   No media
# 20  [https://t.co/Bh6X8I1MeP, https://t.co/RxKCmSZ...       False   No media
# 21  [https://t.co/wg2onqS9Db, https://t.co/wg2onqS...       False   No media
# 8                                                  []       False   No media
# 9                                                  []       False      Image
# 10  [https://t.co/wg2onqS9Db, https://t.co/wg2onqS...       False   No media
#
#                                            image_urls  thread_number
# 13                                                 []              1
# 32                                                 []              2
# 33                                                 []              2
# 37  [https://pbs.twimg.com/media/Ges1F0QXwAAIXxb?f...              3
# 47  [https://pbs.twimg.com/media/GesZBYxaUAAmcL1?f...              4
# 48  [https://pbs.twimg.com/media/GeqzrCZbsAEWiMH?f...              5
# 11                                                 []              6
# 52  [https://pbs.twimg.com/ext_tw_video_thumb/1867...              7
# 39                                                 []              8
# 24                                                 []              9
# 18                                                 []             10
# 41                                                 []             11
# 50                                                 []             12
# 51                                                 []             12
# 42                                                 []             13
# 14  [https://pbs.twimg.com/media/Gexfy7RbEAAscNw?f...             14
# 19                                                 []             15
# 4   [https://pbs.twimg.com/media/GezaXYcbwAAhfoR?f...             16
# 49  [https://pbs.twimg.com/media/GeqzrCZbsAEWiMH?f...             17
# 40  [https://pbs.twimg.com/media/GeixfKxakAAAwpR?f...             18
# 23                                                 []             19
# 17  [https://pbs.twimg.com/media/Gexb_AGa4AAFvKR?f...             20
# 15  [https://pbs.twimg.com/media/Gexfy7RbEAAscNw?f...             21
# 12  [https://pbs.twimg.com/media/GeyJLvVboAAzHkX?f...             22
# 7   [https://pbs.twimg.com/media/GeyJji-akAApsLk?f...             23
# 6   [https://pbs.twimg.com/media/GeyKzZBawAAiNHB?f...             24
# 2   [https://pbs.twimg.com/media/GeyKFQ6bIAAvJQ9?f...             25
# 1   [https://pbs.twimg.com/media/GeyKYWMbAAAgGAg?f...             26
# 53  [https://pbs.twimg.com/media/Ger-2sHbIAAtLT7?f...             27
# 26  [https://pbs.twimg.com/media/GetodZ3bUAArNGW?f...             28
# 16  [https://pbs.twimg.com/media/GexvcXYaYAAejAm?f...             29
# 46                                                 []             30
# 45                                                 []             31
# 44  [https://pbs.twimg.com/media/Gesi2GUXoAEAH0t?f...             32
# 38  [https://pbs.twimg.com/media/Ges1-blWAAAdpEO?f...             33
# 34  [https://pbs.twimg.com/media/GetDkpnXIAAPxoX?f...             34
# 28  [https://pbs.twimg.com/media/GetdsJNXYAAt-g-?f...             35
# 27  [https://pbs.twimg.com/media/GetibopXMAAYGyp?f...             36
# 25  [https://pbs.twimg.com/media/Getrb-hWwAAe7KQ?f...             37
# 22                                                 []             38
# 43                                                 []             39
# 35                                                 []             40
# 36  [https://pbs.twimg.com/media/Ges9g1aXMAAQTLg?f...             40
# 29  [https://pbs.twimg.com/ext_tw_video_thumb/1867...             41
# 30  [https://pbs.twimg.com/ext_tw_video_thumb/1867...             41
# 31                                                 []             41
# 54  [https://pbs.twimg.com/media/GdaTSJ0W0AEbIvy?f...             42
# 5   [https://pbs.twimg.com/media/GexK4LXa4AA5-td?f...             43
# 0                                                  []             44
# 3                                                  []             45
# 20                                                 []             46
# 21                                                 []             47
# 8                                                  []             48
# 9   [https://pbs.twimg.com/media/Geycr4JaoAIWy_W?f...             48
# 10                                                 []             48

# %%
twitter_scraper.download_images(tweets)
# Out:
# Successfully downloaded image: Alec_Coughlin__1867644998495199360_1
# Successfully downloaded image: charu1603__1867614145627271311_1
# Successfully downloaded image: CopilotKit__1867617931619697121_1
# Successfully downloaded image: DeepLearningAI__1867593926682481106_1
# Successfully downloaded image: HardKothari__1868004115114336762_1
# Successfully downloaded image: jerryjliu0__1868109665772646724_1
# Successfully downloaded image: jerryjliu0__1868109665772646724_2
# Successfully downloaded image: LangChainAI__1867611691061850271_1
